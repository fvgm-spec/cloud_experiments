# %%
from faker import Faker
import json
import csv
import pandas as pd
import random

# Initialize Faker
fake = Faker()

json_folder = 'data/json_files/'
csv_folder = 'data/csv-files/'

# %%
def generate_pii_json(num_patients=100, max_claims_per_patient=5):
    data = {
        "patients": [],
        "claims": []
    }
    
    # Generate patient data
    for _ in range(num_patients):
        patient_id = fake.uuid4()
        patient_data = {
            "patient_id": patient_id,
            "name": fake.name(),
            "date_of_birth": fake.date_of_birth(minimum_age=18, maximum_age=90).strftime("%Y-%m-%d"),
            "address": fake.address()
        }
        data["patients"].append(patient_data)
        
        # Generate claims for this patient
        num_claims = random.randint(1, max_claims_per_patient)
        for _ in range(num_claims):
            claim_data = {
                "claim_id": fake.uuid4(),
                "amount": round(random.uniform(100, 5000), 2),  # Random amount between 100 and 5000
                "patient_id": patient_id
            }
            data["claims"].append(claim_data)

    return data

# %%
def generate_pii_csv(output_file: str, num_records: int):
    """
    Generate a CSV file with fake PII data.
    :param output_file: Path to the CSV file to create.
    :param num_records: Number of records to generate.
    """
    fake = Faker()

    # Define the columns for the CSV
    columns = [
        "first_name", 
        "last_name", 
        "birth_date", 
        "address", 
        "city", 
        "state", 
        "zip_code", 
        "email", 
        "phone_number", 
        "ssn", 
        "drivers_license"
    ]

    # Open the output file and write the data
    with open(output_file, mode='w', newline='') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=columns)
        writer.writeheader()  # Write the header row

        for _ in range(num_records):
            # Generate a row of fake data
            record = {
                "first_name": fake.first_name(),
                "last_name": fake.last_name(),
                "birth_date": fake.date_of_birth(minimum_age=18, maximum_age=90).strftime("%Y-%m-%d"),
                "address": fake.street_address(),
                "city": fake.city(),
                "state": fake.state(),
                "zip_code": fake.zipcode(),
                "email": fake.email(),
                "phone_number": fake.phone_number(),
                "ssn": fake.ssn(),
                "drivers_license": fake.license_plate()  # Faker does not have a driver's license, but we can use license_plate
            }

            # Write the record to the CSV file
            writer.writerow(record)

    print(f"CSV file '{output_file}' with {num_records} records has been created.")

# %%
# Generate data with 100 patients and up to 5 claims per patient
data = generate_pii_json(num_patients=10, max_claims_per_patient=5)

# Save to JSON file
with open(f"{json_folder}patients_claims_data.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

# Print sample data
print(json.dumps(data, indent=4))
# Out:
# {
#     "patients": [
#         {
#             "patient_id": "139f40a8-da41-4a5f-b4c1-7e38b2748492",
#             "name": "Amber Craig",
#             "date_of_birth": "1999-08-16",
#             "address": "3604 Norris Junction\nSouth Ericaville, IA 31387"
#         },
#         {
#             "patient_id": "9f81529d-6603-484d-8e8e-507f8e23676d",
#             "name": "Ryan Park",
#             "date_of_birth": "1968-02-04",
#             "address": "8434 Rivers Lock Suite 797\nWest Tanya, PR 52810"
#         },
#         {
#             "patient_id": "dd395454-3ad6-469c-ab51-c55422bea4ff",
#             "name": "Eric Davenport",
#             "date_of_birth": "1986-01-14",
#             "address": "787 Alejandro Springs Suite 533\nLindsayport, CT 20635"
#         },
#         {
#             "patient_id": "7700de5b-d22c-481f-9369-9b6b418b00a9",
#             "name": "Gabriella Campbell",
#             "date_of_birth": "1974-03-27",
#             "address": "1428 Hubbard Dale\nSouth Michael, NV 00659"
#         },
#         {
#             "patient_id": "f255898a-b797-409a-b4ab-a74543a124f2",
#             "name": "Tammy Morrison",
#             "date_of_birth": "1975-05-21",
#             "address": "3936 Hardy Islands Apt. 521\nSolomonside, MS 86427"
#         },
#         {
#             "patient_id": "28c63463-dc6b-4de0-b43b-6c18d090aeb3",
#             "name": "Justin Ellis",
#             "date_of_birth": "1953-09-12",
#             "address": "9759 Donald Street Suite 933\nPetersonshire, MN 91576"
#         },
#         {
#             "patient_id": "4b6b0361-6422-4596-8e48-445c0035ebf3",
#             "name": "Michael Stewart",
#             "date_of_birth": "1938-06-29",
#             "address": "084 Monica Walks\nGatesville, GU 85367"
#         },
#         {
#             "patient_id": "83b0cff5-6319-42a8-b005-4340829370e9",
#             "name": "Stephanie Mitchell",
#             "date_of_birth": "1968-03-11",
#             "address": "2429 Donna Forge\nLake Stephanieview, AZ 31243"
#         },
#         {
#             "patient_id": "cb32623c-b53d-4bc1-9ed3-1e6c438812a2",
#             "name": "Michael Williams",
#             "date_of_birth": "2001-10-26",
#             "address": "3745 Williams Landing\nSouth Melissa, AS 66202"
#         },
#         {
#             "patient_id": "613bb19d-35a1-42a9-8769-0eda9fe0ff92",
#             "name": "Sylvia Grimes",
#             "date_of_birth": "1967-01-30",
#             "address": "0783 Alvarez Ways Suite 971\nNorth Veronicaberg, AK 95277"
#         }
#     ],
#     "claims": [
#         {
#             "claim_id": "58e6f39b-2a7d-47b6-b4d1-177e2433f69f",
#             "amount": 4859.02,
#             "patient_id": "139f40a8-da41-4a5f-b4c1-7e38b2748492"
#         },
#         {
#             "claim_id": "7c819234-66c4-4c88-9971-88ebc13553fb",
#             "amount": 225.99,
#             "patient_id": "139f40a8-da41-4a5f-b4c1-7e38b2748492"
#         },
#         {
#             "claim_id": "65d720e5-48b9-4d80-a6d7-c38112ca563c",
#             "amount": 1059.45,
#             "patient_id": "139f40a8-da41-4a5f-b4c1-7e38b2748492"
#         },
#         {
#             "claim_id": "4344d8ab-bcff-4695-b0d8-7909e658253a",
#             "amount": 3395.24,
#             "patient_id": "9f81529d-6603-484d-8e8e-507f8e23676d"
#         },
#         {
#             "claim_id": "0d31453c-261d-4356-bb76-1b53e384ade9",
#             "amount": 1992.15,
#             "patient_id": "dd395454-3ad6-469c-ab51-c55422bea4ff"
#         },
#         {
#             "claim_id": "ec5f66bc-660e-470f-92a4-07825681e46b",
#             "amount": 3618.32,
#             "patient_id": "dd395454-3ad6-469c-ab51-c55422bea4ff"
#         },
#         {
#             "claim_id": "fd722f27-8eb6-4d94-8f49-52b8a571dd1c",
#             "amount": 2669.92,
#             "patient_id": "dd395454-3ad6-469c-ab51-c55422bea4ff"
#         },
#         {
#             "claim_id": "8fde4ec7-fb68-4255-ac81-afb4a6b2a4fd",
#             "amount": 3491.23,
#             "patient_id": "dd395454-3ad6-469c-ab51-c55422bea4ff"
#         },
#         {
#             "claim_id": "5892de44-abd4-4d4a-b243-ae29b13edc93",
#             "amount": 3846.49,
#             "patient_id": "dd395454-3ad6-469c-ab51-c55422bea4ff"
#         },
#         {
#             "claim_id": "e9646fde-76bd-4e0d-afed-d09746f2ddfd",
#             "amount": 4791.05,
#             "patient_id": "7700de5b-d22c-481f-9369-9b6b418b00a9"
#         },
#         {
#             "claim_id": "99e5e3ba-bd4c-471e-94b4-ed2579b4e732",
#             "amount": 3945.79,
#             "patient_id": "7700de5b-d22c-481f-9369-9b6b418b00a9"
#         },
#         {
#             "claim_id": "d144759b-f6eb-44b6-a429-61683ddc60eb",
#             "amount": 2504.06,
#             "patient_id": "7700de5b-d22c-481f-9369-9b6b418b00a9"
#         },
#         {
#             "claim_id": "e1838f60-14f2-4ed3-aa09-da8ac1d0da64",
#             "amount": 3796.46,
#             "patient_id": "7700de5b-d22c-481f-9369-9b6b418b00a9"
#         },
#         {
#             "claim_id": "3a9b0bab-c248-4ed6-b810-d71bd93d5336",
#             "amount": 4834.07,
#             "patient_id": "f255898a-b797-409a-b4ab-a74543a124f2"
#         },
#         {
#             "claim_id": "dee8cc13-628a-4ee6-ad7f-81f079328335",
#             "amount": 1526.45,
#             "patient_id": "f255898a-b797-409a-b4ab-a74543a124f2"
#         },
#         {
#             "claim_id": "77f53653-3826-4bd1-b817-b0583d94ce4e",
#             "amount": 2069.32,
#             "patient_id": "f255898a-b797-409a-b4ab-a74543a124f2"
#         },
#         {
#             "claim_id": "62f738a9-20f8-442a-a06d-0706db32e424",
#             "amount": 211.52,
#             "patient_id": "f255898a-b797-409a-b4ab-a74543a124f2"
#         },
#         {
#             "claim_id": "d15e419f-7d38-4af6-b8ae-9028598a81e9",
#             "amount": 1048.18,
#             "patient_id": "28c63463-dc6b-4de0-b43b-6c18d090aeb3"
#         },
#         {
#             "claim_id": "ac179012-ff12-48a7-9e35-6e88c4d1c6e9",
#             "amount": 4172.72,
#             "patient_id": "4b6b0361-6422-4596-8e48-445c0035ebf3"
#         },
#         {
#             "claim_id": "32b4d00b-c028-408c-97e0-4636f1d75f5a",
#             "amount": 1811.55,
#             "patient_id": "4b6b0361-6422-4596-8e48-445c0035ebf3"
#         },
#         {
#             "claim_id": "af766348-adaf-4706-ac66-96067f2fa37b",
#             "amount": 3888.44,
#             "patient_id": "4b6b0361-6422-4596-8e48-445c0035ebf3"
#         },
#         {
#             "claim_id": "abae2ab0-03ef-4fbb-a8eb-53e4d0983869",
#             "amount": 2216.73,
#             "patient_id": "83b0cff5-6319-42a8-b005-4340829370e9"
#         },
#         {
#             "claim_id": "4dd00988-4d28-4ea2-8395-1fee1bc9a836",
#             "amount": 4693.31,
#             "patient_id": "83b0cff5-6319-42a8-b005-4340829370e9"
#         },
#         {
#             "claim_id": "e60b4748-ae61-4aa8-9950-9326d6195211",
#             "amount": 337.99,
#             "patient_id": "83b0cff5-6319-42a8-b005-4340829370e9"
#         },
#         {
#             "claim_id": "d02ea478-8725-4849-83ac-b12ed2886489",
#             "amount": 719.76,
#             "patient_id": "cb32623c-b53d-4bc1-9ed3-1e6c438812a2"
#         },
#         {
#             "claim_id": "cd51c252-90ba-488c-93b4-bc32d94d4453",
#             "amount": 3098.14,
#             "patient_id": "613bb19d-35a1-42a9-8769-0eda9fe0ff92"
#         },
#         {
#             "claim_id": "ca9f5de7-2fea-418e-a244-b88c9527cd3a",
#             "amount": 1452.16,
#             "patient_id": "613bb19d-35a1-42a9-8769-0eda9fe0ff92"
#         },
#         {
#             "claim_id": "811e2988-1028-4474-8e9e-60f6e6527c58",
#             "amount": 4616.32,
#             "patient_id": "613bb19d-35a1-42a9-8769-0eda9fe0ff92"
#         },
#         {
#             "claim_id": "60214b3e-01a4-47d6-96ae-d0a2f2b87e09",
#             "amount": 1264.66,
#             "patient_id": "613bb19d-35a1-42a9-8769-0eda9fe0ff92"
#         },
#         {
#             "claim_id": "a249bf7d-acdd-4e6b-b8b8-7ab187261850",
#             "amount": 2137.13,
#             "patient_id": "613bb19d-35a1-42a9-8769-0eda9fe0ff92"
#         }
#     ]
# }

# %%
# Generating CSV PII data
generate_pii_csv(f"{csv_folder}patients_pii_data.csv", 100)
# Out:
# CSV file 'data/csv-files/patients_pii_data.csv' with 100 records has been created.

# %%
from utils.load_to_s3 import upload_files

upload_files(f"{csv_folder}patients_pii_data.csv", 'pii-data-1129', 'patients_pii_data.csv')
# Out:
# File was successfully uploaded to the bucket called pii-data-1129 with the name data/csv-files/patients_pii_data.csv.

# %%
#Reading CSV PII data file from local folder
pii_df = pd.read_csv(f"{csv_folder}patients_pii_data.csv")
pii_df.head()
# Out:
#   first_name last_name  birth_date                         address  \
# 0      Carla        Le  1960-02-18  17140 Bryan Turnpike Suite 604
# 1      Sarah    Bailey  1941-10-26             805 Ashley Crossing
# 2    Michael     Grant  1976-04-01              454 Regina Squares
# 3      David  Crawford  1944-11-14               9965 Helen Manors
# 4    Jessica    Harris  1954-12-08        5724 Tom Roads Suite 679
#
#               city           state  zip_code                    email  \
# 0     Brittanystad    Rhode Island     39660  jacksonrose@example.com
# 1  Port Walterland   New Hampshire     14015      hlawson@example.org
# 2        New Jason         Wyoming     24975        fhill@example.com
# 3   North Marybury  South Carolina     19701        ipace@example.net
# 4     East Jessica      Washington     71216     carrie53@example.com
#
#             phone_number          ssn drivers_license
# 0        +1-423-535-1326  310-02-1588         NO6 O8O
# 1           964.758.5419  481-53-8785         825-VHH
# 2           550-455-1498  475-77-4644        RT 07339
# 3  +1-844-468-7557x74885  119-81-5536        QTV-3149
# 4    (577)653-8717x16128  841-26-6618         328-TWK
